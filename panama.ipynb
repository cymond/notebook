# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("admin/roll_history.csv")
df2 = df[df['CARVER']=='EDOLLAR'].copy()
df2
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>422</th>
#       <td>EDOLLAR</td>
#       <td>1983-09-26</td>
#       <td>198409</td>
#       <td>198412</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>EDOLLAR</td>
#       <td>1983-12-12</td>
#       <td>198412</td>
#       <td>198503</td>
#     </tr>
#     <tr>
#       <th>424</th>
#       <td>EDOLLAR</td>
#       <td>1984-01-12</td>
#       <td>198503</td>
#       <td>198506</td>
#     </tr>
#     <tr>
#       <th>425</th>
#       <td>EDOLLAR</td>
#       <td>1984-04-10</td>
#       <td>198506</td>
#       <td>198509</td>
#     </tr>
#     <tr>
#       <th>426</th>
#       <td>EDOLLAR</td>
#       <td>1984-06-22</td>
#       <td>198509</td>
#       <td>198512</td>
#     </tr>
# ...

# %%
#df2.set_index(['DATETIME'],inplace=True)
df2[0:1]['PRICE_CONTRACT'][0]
# Out:
# 198412

# %%
# Check that maturities exist for price contract
import os
for row in df2.itertuples():
    raw_file = "quandl_history/EDOLLAR" + str(row.CARRY_CONTRACT) + ".csv"
    if not os.path.isfile(raw_file):
        print(raw_file, " is missing!")
        
        
    


    #print(raw_file)
    #print(type(str(row.PRICE_CONTRACT)))

# %%
# NOTES......
# Panama series generation happens between two pandas Dataframes and a splice date
# A Panama Price series and a Raw Price series
# The splice date must exist in both series
# The Panama series is truncated and adjusted by splice day delta at splice date
# The raw Pricce concatenates adjusted Panama series from splice date
# New Panama series

# %%
df2.head(4)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>422</th>
#       <td>EDOLLAR</td>
#       <td>1983-09-26</td>
#       <td>198409</td>
#       <td>198412</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>EDOLLAR</td>
#       <td>1983-12-12</td>
#       <td>198412</td>
#       <td>198503</td>
#     </tr>
#     <tr>
#       <th>424</th>
#       <td>EDOLLAR</td>
#       <td>1984-01-12</td>
#       <td>198503</td>
#       <td>198506</td>
#     </tr>
#     <tr>
#       <th>425</th>
#       <td>EDOLLAR</td>
#       <td>1984-04-10</td>
#       <td>198506</td>
#       <td>198509</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2[0:1]['PRICE_CONTRACT']
# Out:
# DATETIME
# 1983-09-26    198412
# Name: PRICE_CONTRACT, dtype: int64

# %%
pan_file = 'quandl_history/EDOLLAR' + str(df2[0:1]['PRICE_CONTRACT'][0]) + '.csv'
pan_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-951bb3288780> in <module>()
# ----> 1 pan_file = 'quandl_history/EDOLLAR' + str(df2[0:1]['PRICE_CONTRACT'][0]) + '.csv'
#       2 pan_file
#
# NameError: name 'df2' is not defined

# %%
pan_df = pd.read_csv(pan_file, usecols=['Date', 'Settle'], index_col=['Date'],parse_dates=True)
pan_df.head(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1983-09-23</th>
#       <td>88.92</td>
#     </tr>
#     <tr>
#       <th>1983-09-26</th>
#       <td>89.06</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pan_file = 'quandl_history/EDOLLAR201406.csv'
pan_file
# Out:
# 'quandl_history/EDOLLAR201406.csv'

# %%
pan_df.loc['1983-09-26']
# Out:
# Settle    89.06
# Name: 1983-09-26 00:00:00, dtype: float64

# %%
'1983-09-23' in pan_df.index
# Out:
# True

# %%
# First determine that base dataframe is at correct date and the two dataframes contain the splice date
base_df = pan_df.copy()
splice_maturity = df2[1:2]['PRICE_CONTRACT'][0]
splice_maturity
# Out:
# 198503

# %%
splice_date = df2[1:2].index.values[0]
splice_date

# %%
splice_date = df2[1:2].index.values[0]
splice_date
# Out:
# '1983-12-12'

# %%
splice_file = 'quandl_history/EDOLLAR' + str(df2[1:2]['PRICE_CONTRACT'][0]) + '.csv'
splice_df = pd.read_csv(splice_file, usecols=['Date', 'Settle'], index_col=['Date'],parse_dates=True)
splice_df.head(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1983-09-28</th>
#       <td>88.70</td>
#     </tr>
#     <tr>
#       <th>1983-09-29</th>
#       <td>88.68</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
splice_date in pan_df.index
# Out:
# True

# %%
splice_date in splice_df.index
# Out:
# True

# %%
from dbutils.panama import *
new_pandf = pan_splice(pan_df,splice_df,splice_date)
new_pandf
# Out:
# 'Hello'

# %%
new_pandf = pan_df[:splice_date][:-1]
new_pandf.tail(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1983-12-08</th>
#       <td>88.25</td>
#     </tr>
#     <tr>
#       <th>1983-12-09</th>
#       <td>88.22</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
splice_df.loc[splice_date][0]
# Out:
# 88.230000000000004

# %%
delta = splice_df.loc[splice_date][0] - pan_df.loc[splice_date][0]
delta
# Out:
# -0.23999999999999488

# %%
copy = new_pandf.copy()
print(copy.head(2))
# Out:
#             Settle
# Date
# 1983-09-28   88.70
# 1983-09-29   88.68

# %%
newdf = copy[:-10]['Settle'] + 200

# %%
newdf.tail(2)
# Out:
# Date
# 1983-11-22    288.49
# 1983-11-23    288.50
# Name: Settle, dtype: float64

# %%
splice_date
# Out:
# '1983-12-12'

# %%
pan_df.tail(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1984-12-14</th>
#       <td>90.96</td>
#     </tr>
#     <tr>
#       <th>1984-12-17</th>
#       <td>91.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
panama_df = pan_splice(pan_df,newdf,splice_date)
panama_df.head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-315d4b76ab4d> in <module>()
#       1 panama_df = pan_splice(pan_df,newdf,splice_date)
# ----> 2 panama_df.head(2)
#
# AttributeError: 'str' object has no attribute 'head'

# %%
roll_df = pd.read_csv("admin/roll_history.csv", dtype={'CARVER':str, 'PRICE_CONTRACT': str})
edollar_rolls_df = roll_df[roll_df['CARVER']=='EDOLLAR'].copy()
#pan_file = 'quandl_history/EDOLLAR' + str(edollar_rolls_df[0:1]['PRICE_CONTRACT'][0]) + '.csv'
this = str(edollar_rolls_df[0:1]['PRICE_CONTRACT'])
this
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-33c06e560702> in <module>()
# ----> 1 roll_df = pd.read_csv("admin/roll_history.csv", dtype={'CARVER':str, 'PRICE_CONTRACT': str})
#       2 edollar_rolls_df = roll_df[roll_df['CARVER']=='EDOLLAR'].copy()
#       3 #pan_file = 'quandl_history/EDOLLAR' + str(edollar_rolls_df[0:1]['PRICE_CONTRACT'][0]) + '.csv'
#       4 this = str(edollar_rolls_df[0:1]['PRICE_CONTRACT'])
#       5 this
#
# NameError: name 'pd' is not defined

# %%
edollar_rolls_df[0:1]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>56</th>
#       <td>EDOLLAR</td>
#       <td>1983-09-26</td>
#       <td>198409</td>
#       <td>198412</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
edollar_rolls_df.iloc[0]['PRICE_CONTRACT']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2975dfd17977> in <module>()
# ----> 1 edollar_rolls_df.iloc[0]['PRICE_CONTRACT']
#
# NameError: name 'edollar_rolls_df' is not defined

# %%
edollar_rolls_df.axes[0:1]
# Out:
# [Int64Index([ 56,  57,  58,  59,  60,  61,  62,  63,  64,  65,
#              ...
#              181, 182, 183, 184, 185, 186, 187, 188, 189, 190],
#             dtype='int64', length=135)]

# %%
splice_date = edollar_rolls_df.iloc[1]['DATETIME']
splice_date
# Out:
# '1983-12-12'

# %%
type(splice_date)
# Out:
# str

# %%
pan_df[:splice_date]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1983-09-23</th>
#       <td>88.92</td>
#     </tr>
#     <tr>
#       <th>1983-09-26</th>
#       <td>89.06</td>
#     </tr>
#     <tr>
#       <th>1983-09-27</th>
#       <td>88.95</td>
#     </tr>
#     <tr>
#       <th>1983-09-28</th>
#       <td>88.90</td>
#     </tr>
#     <tr>
#       <th>1983-09-29</th>
#       <td>88.88</td>
#     </tr>
#     <tr>
#       <th>1983-09-30</th>
#       <td>88.92</td>
#     </tr>
#     <tr>
#       <th>1983-10-03</th>
#       <td>88.95</td>
#     </tr>
#     <tr>
#       <th>1983-10-04</th>
#       <td>88.95</td>
#     </tr>
#     <tr>
#       <th>1983-10-05</th>
#       <td>89.01</td>
#     </tr>
#     <tr>
#       <th>1983-10-06</th>
#       <td>89.02</td>
#     </tr>
#     <tr>
# ...

# %%
type(pan_df.index.values[0])
# Out:
# numpy.datetime64

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
print(round((0.3 - 0.1),5))
# Out:
# 0.2

# %%
round(2.675, 2)
# Out:
# 2.67

# %%
from decimal import *
print(getcontext())
# Out:
# Context(prec=28, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])

# %%
getcontext().prec = 6
Decimal('3.0')
# Out:
# Decimal('3.0')

# %%
Decimal(3.0)
# Out:
# Decimal('3')

# %%
print(Decimal(2.56)* 5)

# %%
Decimal('3.1415926535') + Decimal('2.7182818285')
# Out:
# Decimal('5.85987')

# %%
import pandas as pd
roll_df = pd.read_csv("admin/roll_history.csv", dtype={'CARVER':str, 'PRICE_CONTRACT': str} )
edollar_rolls_df = roll_df[roll_df['CARVER']=='EDOLLAR'].copy()

pan_file = 'quandl_history/EDOLLAR' + edollar_rolls_df.iloc[0]['PRICE_CONTRACT'] + '.csv'
pan_df = pd.read_csv(pan_file, usecols=['Date', 'Settle'], \
                       index_col=['Date'],parse_dates=True, \
                        dtype = {'Settle': Decimal})

print(type(pan_df.iloc[0]['Settle']))
# Out:
# <class 'str'>

# %%
b = '199.0362'
result = Decimal(float(b))
result
# Out:
# Decimal('199.03620000000000800355337560176849365234375')

# %%
getcontext().prec = 4
c = Decimal('3.02')
c
# Out:
# Decimal('3.02')

# %%
c + 2
# Out:
# Decimal('5.020')

# %%
str(c)
# Out:
# '3.02'

# %%
'data/EDOLLAR_price.csv'[5:][:-10]
# Out:
# 'EDOLLAR'

# %%
try:
    df = pd.read_csv('data/anyfile')
except EmptyDataError :
    pass
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-41-91006f2fa0ab> in <module>()
#       1 try:
# ----> 2     df = pd.read_csv('data/anyfile')
#       3 except EmptyDataError :
#
# ...

# %%
df = pd.read_csv('data/anyfile')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-43-17c24d3c512d> in <module>()
# ----> 1 df = pd.read_csv('data/anyfile')
#
# ...

# %%
try:
    pd.read_csv('data/anyfile')
except Exeption as e:
    print(str(e))
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-45-6a8e41fe8053> in <module>()
#       1 try:
# ----> 2     pd.read_csv('data/anyfile')
#       3 except Exeption as e:
#
# ...

# %%
import os    
os.path.getsize('data/ayfile') > 0
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-96ecf16896a8> in <module>()
#       1 import os
# ----> 2 os.path.getsize('data/ayfile') > 0
#
# /usr/lib/python3.5/genericpath.py in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#      51
#      52
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ayfile'

# %%
pan_file = 'quandl_history/EDOLLAR' + edollar_rolls_df.iloc[0]['PRICE_CONTRACT'] + '.csv'
pan_df = pd.read_csv(pan_file, usecols=['Date', 'Settle','Open'], \
                       index_col=['Date'],parse_dates=True, \
                        dtype = {'Settle': float})
pan_df.tail(3)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Open</th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1984-12-13</th>
#       <td>90.75</td>
#       <td>90.70</td>
#     </tr>
#     <tr>
#       <th>1984-12-14</th>
#       <td>90.77</td>
#       <td>90.96</td>
#     </tr>
#     <tr>
#       <th>1984-12-17</th>
#       <td>90.97</td>
#       <td>91.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pan_df.index.names = ['DATETIME']
pan_df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Close</th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>DATETIME</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1983-09-23</th>
#       <td>88.92</td>
#       <td>88.92</td>
#     </tr>
#     <tr>
#       <th>1983-09-26</th>
#       <td>89.02</td>
#       <td>89.06</td>
#     </tr>
#     <tr>
#       <th>1983-09-27</th>
#       <td>89.00</td>
#       <td>88.95</td>
#     </tr>
#     <tr>
#       <th>1983-09-28</th>
#       <td>89.00</td>
#       <td>88.90</td>
#     </tr>
#     <tr>
#       <th>1983-09-29</th>
#       <td>88.85</td>
#       <td>88.88</td>
#     </tr>
#     <tr>
#       <th>1983-09-30</th>
#       <td>88.86</td>
#       <td>88.92</td>
#     </tr>
#     <tr>
#       <th>1983-10-03</th>
#       <td>88.95</td>
#       <td>88.95</td>
#     </tr>
#     <tr>
# ...

# %%
alist = [{"file": "options/donimo.csv", "date": 12},{"file": "options/batibos", "date": 23}]

# %%
for dict in alist:
    print(dict["file"])
# Out:
# options/donimo.csv
# options/batibos

# %%
import pandas as pd
import numpy as np
from dbutils.panama import *

roll_df = pd.read_csv("admin/roll_history.csv", dtype={'CARVER':str, 'PRICE_CONTRACT': str} )
edollar_rolls_df = roll_df[roll_df['CARVER']=='EDOLLAR'].copy()
edollar_rolls_df.head(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>56</th>
#       <td>EDOLLAR</td>
#       <td>1983-09-26</td>
#       <td>198409</td>
#       <td>198412</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>EDOLLAR</td>
#       <td>1983-12-12</td>
#       <td>198412</td>
#       <td>198503</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df5 = pd.DataFrame(alist)
df5
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>file</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12</td>
#       <td>options/donimo.csv</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>23</td>
#       <td>options/batibos</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dff = pd.read_csv('quandl_history/EDOLLAR198412.csv', usecols=['Date', 'Settle'], \
                                      index_col=['Date'],parse_dates=True, \
                                      dtype={'Settle': float})
dff.tail(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1984-12-14</th>
#       <td>90.96</td>
#     </tr>
#     <tr>
#       <th>1984-12-17</th>
#       <td>91.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dff = dff.round(1)
dff
# Out:
# Date
# 1983-09-23    88.9
# 1983-09-26    89.1
# 1983-09-27    89.0
# 1983-09-28    88.9
# 1983-09-29    88.9
# 1983-09-30    88.9
# 1983-10-03    89.0
# 1983-10-04    89.0
# 1983-10-05    89.0
# 1983-10-06    89.0
# 1983-10-07    89.0
# 1983-10-10    89.0
# 1983-10-11    88.9
# 1983-10-12    88.9
# 1983-10-13    88.9
# 1983-10-14    88.9
# 1983-10-17    89.1
# 1983-10-18    89.0
# 1983-10-19    89.0
# 1983-10-20    89.0
# 1983-10-21    89.0
# 1983-10-24    88.9
# 1983-10-25    88.8
# 1983-10-26    88.8
# 1983-10-27    88.9
# 1983-10-28    88.8
# 1983-10-31    88.8
# 1983-11-01    88.8
# 1983-11-02    88.8
# 1983-11-03    88.7
#               ...
# 1984-11-05    90.2
# 1984-11-06    90.2
# 1984-11-07    90.1
# 1984-11-08    90.0
# 1984-11-09    90.1
# 1984-11-12    90.2
# 1984-11-13    90.0
# 1984-11-14    90.0
# 1984-11-15    90.2
# 1984-11-16    90.2
# 1984-11-19    90.3
# 1984-11-20    90.3
# 1984-11-21    90.5
# 1984-11-23    90.6
# 1984-11-26    90.6
# 1984-11-27    90.6
# ...

# %%
df = pd.DataFrame(np.random.random([3, 3]),
    columns=['A', 'B', 'C'], index=['first', 'second', 'third'])
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.400773</td>
#       <td>0.347223</td>
#       <td>0.990204</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.412917</td>
#       <td>0.734191</td>
#       <td>0.959140</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.160279</td>
#       <td>0.225279</td>
#       <td>0.959942</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2 = df.round({'A' : 2})
df2
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.40</td>
#       <td>0.347223</td>
#       <td>0.990204</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.41</td>
#       <td>0.734191</td>
#       <td>0.959140</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.16</td>
#       <td>0.225279</td>
#       <td>0.959942</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2
# Out:
# first     0.40
# second    0.41
# third     0.16
# Name: A, dtype: float64

# %%
print('data/EDOLLAR_carrydata.csv'[5:][:-14])
# Out:
# EDOLLAR

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('mysql+pymysql://root:admin@0.0.0.0/pkdemo')
try:
    df = pd.read_sql_table("aex201406", engine)
    df.size
except Exception as e:
    print(e)

# %%
print(df.head(4))
# Out:
#          Date  Settle
# 0  2013-10-08   364.4
# 1  2013-10-09   360.4
# 2  2013-10-10   366.9
# 3  2013-10-11   369.4

# %%
'EDOLLAR'.lower()
# Out:
# 'edollar'

# %%
import pandas as pd
df = pd.read_csv('quandl_history/EDOLLAR198412.csv', usecols=['Date', 'Settle'], \
                                      index_col=['Date'],parse_dates=True, \
                                      dtype={'Settle': float})
df.tail(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1984-12-14</th>
#       <td>90.96</td>
#     </tr>
#     <tr>
#       <th>1984-12-17</th>
#       <td>91.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print(df.index)
# Out:
# DatetimeIndex(['1983-09-23', '1983-09-26', '1983-09-27', '1983-09-28',
#                '1983-09-29', '1983-09-30', '1983-10-03', '1983-10-04',
#                '1983-10-05', '1983-10-06',
#                ...
#                '1984-12-04', '1984-12-05', '1984-12-06', '1984-12-07',
#                '1984-12-10', '1984-12-11', '1984-12-12', '1984-12-13',
#                '1984-12-14', '1984-12-17'],
#               dtype='datetime64[ns]', name='Date', length=312, freq=None)

# %%
df.index[-1]
# Out:
# Timestamp('1984-12-17 00:00:00')

# %%
df2[-1:].index.values.size
# Out:
# 1

# %%
df2[-1:].iloc[0]['CARRY_CONTRACT']
# Out:
# 201912

# %%
df2.iloc[-1]['CARRY_CONTRACT']
# Out:
# 201912

# %%
'serious'[2:6]
# Out:
# ''

# %%
df.size
# Out:
# 312

# %%
type(df.loc[:'1984-12-17'])
# Out:
# pandas.core.frame.DataFrame

# %%
len(df.index)
# Out:
# 312

# %%
len(df)
# Out:
# 312

# %%
df[0:312]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1983-09-23</th>
#       <td>88.92</td>
#     </tr>
#     <tr>
#       <th>1983-09-26</th>
#       <td>89.06</td>
#     </tr>
#     <tr>
#       <th>1983-09-27</th>
#       <td>88.95</td>
#     </tr>
#     <tr>
#       <th>1983-09-28</th>
#       <td>88.90</td>
#     </tr>
#     <tr>
#       <th>1983-09-29</th>
#       <td>88.88</td>
#     </tr>
#     <tr>
#       <th>1983-09-30</th>
#       <td>88.92</td>
#     </tr>
#     <tr>
#       <th>1983-10-03</th>
#       <td>88.95</td>
#     </tr>
#     <tr>
#       <th>1983-10-04</th>
#       <td>88.95</td>
#     </tr>
#     <tr>
#       <th>1983-10-05</th>
#       <td>89.01</td>
#     </tr>
#     <tr>
#       <th>1983-10-06</th>
#       <td>89.02</td>
#     </tr>
#     <tr>
# ...

# %%
'aex201204'[-6:]
# Out:
# '201204'

# %%
df2['PRICE_CONTRACT']
# Out:
# 59     198412
# 60     198503
# 61     198506
# 62     198509
# 63     198512
# 64     198603
# 65     198606
# 66     198609
# 67     198612
# 68     198703
# 69     198706
# 70     198709
# 71     198712
# 72     198803
# 73     198806
# 74     198812
# 75     198903
# 76     198906
# 77     198912
# 78     199003
# 79     199006
# 80     199009
# 81     199012
# 82     199103
# 83     199106
# 84     199109
# 85     199112
# 86     199203
# 87     199206
# 88     199209
#         ...
# 164    201209
# 165    201212
# 166    201303
# 167    201306
# 168    201309
# 169    201312
# 170    201403
# 171    201406
# 172    201409
# 173    201412
# 174    201503
# 175    201506
# 176    201509
# 177    201512
# 178    201603
# 179    201606
# 180    201609
# 181    201703
# 182    201706
# 183    201709
# 184    201712
# 185    201803
# 186    201806
# 187    201809
# 188    201812
# 189    201903
# 190    201906
# 191    201909
# 192    201912
# 193    202003
# ...

# %%
df2['PRICE_CONTRACT'][2:0]
# Out:
# Series([], Name: PRICE_CONTRACT, dtype: int64)

# %%
205912 in df2['PRICE_CONTRACT'].values
# Out:
# False

# %%
import pandas as pd
splice_df = pd.read_csv(pan_file, usecols=['Date', 'Settle'], index_col=['Date'],parse_dates=True)
splice_df.head(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2004-09-20</th>
#       <td>93.785</td>
#     </tr>
#     <tr>
#       <th>2004-09-21</th>
#       <td>93.825</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
splice_df.loc[splice_df[0:].index[0]][0]
# Out:
# 93.784999999999997

# %%
splice_df.index[-1]
# Out:
# Timestamp('2014-06-16 00:00:00')

# %%
splice_df.loc[splice_df.index[1]:]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2004-09-21</th>
#       <td>93.8250</td>
#     </tr>
#     <tr>
#       <th>2004-09-22</th>
#       <td>93.9050</td>
#     </tr>
#     <tr>
#       <th>2004-09-23</th>
#       <td>93.9050</td>
#     </tr>
#     <tr>
#       <th>2004-09-24</th>
#       <td>93.8850</td>
#     </tr>
#     <tr>
#       <th>2004-09-27</th>
#       <td>93.9350</td>
#     </tr>
#     <tr>
#       <th>2004-09-28</th>
#       <td>93.8900</td>
#     </tr>
#     <tr>
#       <th>2004-09-29</th>
#       <td>93.7900</td>
#     </tr>
#     <tr>
#       <th>2004-09-30</th>
#       <td>93.7300</td>
#     </tr>
#     <tr>
#       <th>2004-10-01</th>
#       <td>93.6400</td>
#     </tr>
#     <tr>
#       <th>2004-10-04</th>
#       <td>93.6850</td>
#     </tr>
# ...

# %%
splice_df.loc[splice_df.index[-1]:]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-06-16</th>
#       <td>99.7694</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
len(splice_df.loc[splice_df.index[-1]:])
# Out:
# 1

# %%
from dbutils.panama import *
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:admin@0.0.0.0/pkdemo')

roll_df = pd.read_csv("admin/roll_history.csv", \
                      dtype={'CARVER':str, 'PRICE_CONTRACT': str, \
                              'CARRY_CONTRACT':str})

len(roll_df)
# Out:
#   File "/home/lope/PycharmProjects/notebook/dbutils/panama.py", line 200
#     carry_mat =
#                ^
# SyntaxError: invalid syntax

# %%
print(roll_df.tail(5))
# Out:
#      CARVER    DATETIME CARRY_CONTRACT PRICE_CONTRACT
# 2401   US20  2016-02-19         201609         201606
# 2402   US20  2016-05-20         201612         201609
# 2403   US20  2016-08-30         201703         201612
# 2404   US20  2016-11-23         201706         201703
# 2405   US20  2017-02-23         201709         201706

# %%
us20 = roll_df[roll_df['CARVER']=='US20' ]

# %%
us = us20[us20['PRICE_CONTRACT'] > '197903']
us
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2248</th>
#       <td>US20</td>
#       <td>1977-08-23</td>
#       <td>197806</td>
#       <td>197803</td>
#     </tr>
#     <tr>
#       <th>2249</th>
#       <td>US20</td>
#       <td>1978-01-24</td>
#       <td>197809</td>
#       <td>197806</td>
#     </tr>
#     <tr>
#       <th>2250</th>
#       <td>US20</td>
#       <td>1978-04-26</td>
#       <td>197812</td>
#       <td>197809</td>
#     </tr>
#     <tr>
#       <th>2251</th>
#       <td>US20</td>
#       <td>1978-07-27</td>
#       <td>197903</td>
#       <td>197812</td>
#     </tr>
#     <tr>
#       <th>2252</th>
#       <td>US20</td>
#       <td>1978-10-26</td>
#       <td>197906</td>
#       <td>197903</td>
#     </tr>
#     <tr>
# ...

# %%
us = us20[us20             ]
us[us['PRICE_CONTRACT'] < '198006']
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2253</th>
#       <td>US20</td>
#       <td>1979-01-24</td>
#       <td>197909</td>
#       <td>197906</td>
#     </tr>
#     <tr>
#       <th>2254</th>
#       <td>US20</td>
#       <td>1979-04-26</td>
#       <td>197912</td>
#       <td>197909</td>
#     </tr>
#     <tr>
#       <th>2255</th>
#       <td>US20</td>
#       <td>1979-07-27</td>
#       <td>198003</td>
#       <td>197912</td>
#     </tr>
#     <tr>
#       <th>2256</th>
#       <td>US20</td>
#       <td>1979-10-26</td>
#       <td>198006</td>
#       <td>198003</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.tail(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1984-12-14</th>
#       <td>90.96</td>
#     </tr>
#     <tr>
#       <th>1984-12-17</th>
#       <td>91.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df[-1:]['Settle']
# Out:
# Date
# 1984-12-17    91.05
# Name: Settle, dtype: float64

# %%
import pandas as pd

roll_df = pd.read_csv("admin/roll_history.csv", \
                      dtype={'CARVER':str, 'PRICE_CONTRACT': str, \
                              'CARRY_CONTRACT':str},
                      parse_dates=True)

len(roll_df)
# Out:
# 2406

# %%
roll_df.iloc(-1)[0]['PRICE_CONTRACT']
# Out:
# '201312'

# %%
df.tail(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1984-12-14</th>
#       <td>90.96</td>
#     </tr>
#     <tr>
#       <th>1984-12-17</th>
#       <td>91.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
type(df.iloc[-1])
# Out:
# pandas.core.series.Series

# %%
df.index.values
# Out:
# array(['1983-09-23T00:00:00.000000000', '1983-09-26T00:00:00.000000000',
#        '1983-09-27T00:00:00.000000000', '1983-09-28T00:00:00.000000000',
#        '1983-09-29T00:00:00.000000000', '1983-09-30T00:00:00.000000000',
#        '1983-10-03T00:00:00.000000000', '1983-10-04T00:00:00.000000000',
#        '1983-10-05T00:00:00.000000000', '1983-10-06T00:00:00.000000000',
#        '1983-10-07T00:00:00.000000000', '1983-10-10T00:00:00.000000000',
#        '1983-10-11T00:00:00.000000000', '1983-10-12T00:00:00.000000000',
#        '1983-10-13T00:00:00.000000000', '1983-10-14T00:00:00.000000000',
#        '1983-10-17T00:00:00.000000000', '1983-10-18T00:00:00.000000000',
#        '1983-10-19T00:00:00.000000000', '1983-10-20T00:00:00.000000000',
#        '1983-10-21T00:00:00.000000000', '1983-10-24T00:00:00.000000000',
#        '1983-10-25T00:00:00.000000000', '1983-10-26T00:00:00.000000000',
#        '1983-10-27T00:00:00.000000000', '1983-10-28T00:00:00.000000000',
# ...

# %%
df.loc[df.index.values[-1]].index
# Out:
# Index(['Settle'], dtype='object')

# %%
index5 = df[-5:].index.values[0]

# %%
df[-1:].index[0].value
# Out:
# 472089600000000000

# %%
df.head(1)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1983-09-23</th>
#       <td>88.92</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.loc[index5:]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Settle</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1984-12-11</th>
#       <td>90.64</td>
#     </tr>
#     <tr>
#       <th>1984-12-12</th>
#       <td>90.71</td>
#     </tr>
#     <tr>
#       <th>1984-12-13</th>
#       <td>90.70</td>
#     </tr>
#     <tr>
#       <th>1984-12-14</th>
#       <td>90.96</td>
#     </tr>
#     <tr>
#       <th>1984-12-17</th>
#       <td>91.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df[-1:]['Settle'][0]
# Out:
# 91.049999999999997

# %%
v2x = roll_df[roll_df['CARVER'] == 'V2X']

# %%
import datetime

datetime.datetime.now()
# Out:
# datetime.datetime(2017, 5, 25, 14, 18, 34, 684040)

# %%
v2x[v2x['DATETIME'] < datetime.datetime.now()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2f5101ce88a7> in <module>()
# ----> 1 v2x[v2x['DATETIME'] < datetime.datetime.now()]
#
# /home/lope/envs/notebook/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# /home/lope/envs/notebook/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# /home/lope/envs/notebook/lib/python3.5/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
# ...

# %%
roll_df.tail(2)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2404</th>
#       <td>US20</td>
#       <td>2016-11-23</td>
#       <td>201706</td>
#       <td>201703</td>
#     </tr>
#     <tr>
#       <th>2405</th>
#       <td>US20</td>
#       <td>2017-02-23</td>
#       <td>201709</td>
#       <td>201706</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import pandas as pd
roll_df = pd.read_csv("admin/roll_history.csv", \
                      dtype={'CARVER':str, 'PRICE_CONTRACT': str, \
                              'CARRY_CONTRACT':str},
                      parse_dates=['DATETIME'])

# %%
roll_df.tail(4)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2402</th>
#       <td>US20</td>
#       <td>2016-05-20</td>
#       <td>201612</td>
#       <td>201609</td>
#     </tr>
#     <tr>
#       <th>2403</th>
#       <td>US20</td>
#       <td>2016-08-30</td>
#       <td>201703</td>
#       <td>201612</td>
#     </tr>
#     <tr>
#       <th>2404</th>
#       <td>US20</td>
#       <td>2016-11-23</td>
#       <td>201706</td>
#       <td>201703</td>
#     </tr>
#     <tr>
#       <th>2405</th>
#       <td>US20</td>
#       <td>2017-02-23</td>
#       <td>201709</td>
#       <td>201706</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
today = datetime.datetime.now()

# %%
roll_df[roll_df['DATETIME'] < today]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4807fe01dc18> in <module>()
# ----> 1 roll_df[roll_df['DATETIME'] < today]
#
# NameError: name 'roll_df' is not defined

# %%
rolla = roll_df[(roll_df['CARVER'] == 'US20') & (roll_df['PRICE_CONTRACT'] =='201612')]

# %%
rolla.iloc[0]['DATETIME']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-ff662942dc8f> in <module>()
# ----> 1 rolla.iloc[0]['DATETIME'][0]
#
# TypeError: 'Timestamp' object does not support indexing

# %%
import pandas as pd

# %%
df = pd.read_csv("admin/roll_history.csv")
df2 = df[df['CARVER']=='EDOLLAR'].copy()
df2
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>422</th>
#       <td>EDOLLAR</td>
#       <td>1983-09-26</td>
#       <td>198409</td>
#       <td>198412</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>EDOLLAR</td>
#       <td>1983-12-12</td>
#       <td>198412</td>
#       <td>198503</td>
#     </tr>
#     <tr>
#       <th>424</th>
#       <td>EDOLLAR</td>
#       <td>1984-01-12</td>
#       <td>198503</td>
#       <td>198506</td>
#     </tr>
#     <tr>
#       <th>425</th>
#       <td>EDOLLAR</td>
#       <td>1984-04-10</td>
#       <td>198506</td>
#       <td>198509</td>
#     </tr>
#     <tr>
#       <th>426</th>
#       <td>EDOLLAR</td>
#       <td>1984-06-22</td>
#       <td>198509</td>
#       <td>198512</td>
#     </tr>
# ...

# %%
for row in df2.itertuples():
    print(row.DATETIME)
    print(row)
# Out:
# 1983-09-26
# Pandas(Index=422, CARVER='EDOLLAR', DATETIME='1983-09-26', CARRY_CONTRACT=198409, PRICE_CONTRACT=198412)
# 1983-12-12
# Pandas(Index=423, CARVER='EDOLLAR', DATETIME='1983-12-12', CARRY_CONTRACT=198412, PRICE_CONTRACT=198503)
# 1984-01-12
# Pandas(Index=424, CARVER='EDOLLAR', DATETIME='1984-01-12', CARRY_CONTRACT=198503, PRICE_CONTRACT=198506)
# 1984-04-10
# Pandas(Index=425, CARVER='EDOLLAR', DATETIME='1984-04-10', CARRY_CONTRACT=198506, PRICE_CONTRACT=198509)
# 1984-06-22
# Pandas(Index=426, CARVER='EDOLLAR', DATETIME='1984-06-22', CARRY_CONTRACT=198509, PRICE_CONTRACT=198512)
# 1984-08-31
# Pandas(Index=427, CARVER='EDOLLAR', DATETIME='1984-08-31', CARRY_CONTRACT=198512, PRICE_CONTRACT=198603)
# 1984-10-09
# Pandas(Index=428, CARVER='EDOLLAR', DATETIME='1984-10-09', CARRY_CONTRACT=198603, PRICE_CONTRACT=198606)
# 1985-01-08
# Pandas(Index=429, CARVER='EDOLLAR', DATETIME='1985-01-08', CARRY_CONTRACT=198606, PRICE_CONTRACT=198609)
# 1985-04-10
# ...

# %%
df = df2[-10:None]
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>549</th>
#       <td>EDOLLAR</td>
#       <td>2014-10-24</td>
#       <td>201803</td>
#       <td>201806</td>
#     </tr>
#     <tr>
#       <th>550</th>
#       <td>EDOLLAR</td>
#       <td>2015-02-24</td>
#       <td>201806</td>
#       <td>201809</td>
#     </tr>
#     <tr>
#       <th>551</th>
#       <td>EDOLLAR</td>
#       <td>2015-08-31</td>
#       <td>201809</td>
#       <td>201812</td>
#     </tr>
#     <tr>
#       <th>552</th>
#       <td>EDOLLAR</td>
#       <td>2015-11-17</td>
#       <td>201812</td>
#       <td>201903</td>
#     </tr>
#     <tr>
#       <th>553</th>
#       <td>EDOLLAR</td>
#       <td>2016-02-22</td>
#       <td>201903</td>
#       <td>201906</td>
#     </tr>
# ...

# %%
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>422</th>
#       <td>EDOLLAR</td>
#       <td>1983-09-26</td>
#       <td>198409</td>
#       <td>198412</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>EDOLLAR</td>
#       <td>1983-12-12</td>
#       <td>198412</td>
#       <td>198503</td>
#     </tr>
#     <tr>
#       <th>424</th>
#       <td>EDOLLAR</td>
#       <td>1984-01-12</td>
#       <td>198503</td>
#       <td>198506</td>
#     </tr>
#     <tr>
#       <th>425</th>
#       <td>EDOLLAR</td>
#       <td>1984-04-10</td>
#       <td>198506</td>
#       <td>198509</td>
#     </tr>
#     <tr>
#       <th>426</th>
#       <td>EDOLLAR</td>
#       <td>1984-06-22</td>
#       <td>198509</td>
#       <td>198512</td>
#     </tr>
# ...

# %%
df2
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>DATETIME</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>422</th>
#       <td>EDOLLAR</td>
#       <td>1983-09-26</td>
#       <td>198409</td>
#       <td>198412</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>EDOLLAR</td>
#       <td>1983-12-12</td>
#       <td>198412</td>
#       <td>198503</td>
#     </tr>
#     <tr>
#       <th>424</th>
#       <td>EDOLLAR</td>
#       <td>1984-01-12</td>
#       <td>198503</td>
#       <td>198506</td>
#     </tr>
#     <tr>
#       <th>425</th>
#       <td>EDOLLAR</td>
#       <td>1984-04-10</td>
#       <td>198506</td>
#       <td>198509</td>
#     </tr>
#     <tr>
#       <th>426</th>
#       <td>EDOLLAR</td>
#       <td>1984-06-22</td>
#       <td>198509</td>
#       <td>198512</td>
#     </tr>
# ...

# %%
df.set_index(['DATETIME'], inplace=True)
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#     <tr>
#       <th>DATETIME</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-10-24</th>
#       <td>EDOLLAR</td>
#       <td>201803</td>
#       <td>201806</td>
#     </tr>
#     <tr>
#       <th>2015-02-24</th>
#       <td>EDOLLAR</td>
#       <td>201806</td>
#       <td>201809</td>
#     </tr>
#     <tr>
#       <th>2015-08-31</th>
#       <td>EDOLLAR</td>
#       <td>201809</td>
#       <td>201812</td>
#     </tr>
#     <tr>
#       <th>2015-11-17</th>
#       <td>EDOLLAR</td>
#       <td>201812</td>
#       <td>201903</td>
#     </tr>
#     <tr>
#       <th>2016-02-22</th>
#       <td>EDOLLAR</td>
#       <td>201903</td>
#       <td>201906</td>
#     </tr>
#     <tr>
# ...

# %%
db = df[2:None]

# %%
db
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#     <tr>
#       <th>DATETIME</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015-08-31</th>
#       <td>EDOLLAR</td>
#       <td>201809</td>
#       <td>201812</td>
#     </tr>
#     <tr>
#       <th>2015-11-17</th>
#       <td>EDOLLAR</td>
#       <td>201812</td>
#       <td>201903</td>
#     </tr>
#     <tr>
#       <th>2016-02-22</th>
#       <td>EDOLLAR</td>
#       <td>201903</td>
#       <td>201906</td>
#     </tr>
#     <tr>
#       <th>2016-08-12</th>
#       <td>EDOLLAR</td>
#       <td>201906</td>
#       <td>201909</td>
#     </tr>
#     <tr>
#       <th>2016-11-15</th>
#       <td>EDOLLAR</td>
#       <td>201909</td>
#       <td>201912</td>
#     </tr>
#     <tr>
# ...

# %%
import datetime
today = datetime.datetime.now()
pd.isnull(today)
# Out:
# False

# %%
pd.isnull(None)
# Out:
# True

# %%
print(str(None))
# Out:
# None

# %%
print(str(pd.NaT))
# Out:
# NaT

# %%
db[pd.NaT:pd.NaT]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CARVER</th>
#       <th>CARRY_CONTRACT</th>
#       <th>PRICE_CONTRACT</th>
#     </tr>
#     <tr>
#       <th>DATETIME</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015-08-31</th>
#       <td>EDOLLAR</td>
#       <td>201809</td>
#       <td>201812</td>
#     </tr>
#     <tr>
#       <th>2015-11-17</th>
#       <td>EDOLLAR</td>
#       <td>201812</td>
#       <td>201903</td>
#     </tr>
#     <tr>
#       <th>2016-02-22</th>
#       <td>EDOLLAR</td>
#       <td>201903</td>
#       <td>201906</td>
#     </tr>
#     <tr>
#       <th>2016-08-12</th>
#       <td>EDOLLAR</td>
#       <td>201906</td>
#       <td>201909</td>
#     </tr>
#     <tr>
#       <th>2016-11-15</th>
#       <td>EDOLLAR</td>
#       <td>201909</td>
#       <td>201912</td>
#     </tr>
#     <tr>
# ...

# %%
print(today + None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f6a5fc1284c6> in <module>()
# ----> 1 print(today + None)
#
# TypeError: unsupported operand type(s) for +: 'datetime.datetime' and 'NoneType'
