# %%
import pandas as pd
import numpy as np

# %%
# If column AAA >= 5, set 'BBB' to 77
df.ix[df.AAA >= 5,'BBB'] = 77; df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ad75cea89ca0> in <module>()
#       1 # If column AAA >= 5, set 'BBB' to 77
# ----> 2 df.ix[df.AAA >= 5,'BBB'] = 77; df
#
# NameError: name 'df' is not defined

# %%
# Dataframe mask
df = pd.DataFrame(np.arange(10).reshape(-1, 2), columns=['A', 'B'])

# %%
df.iloc[df.index.indexer_between_time('1:15', '02:00')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-997931c39f21> in <module>()
# ----> 1 df.iloc[df.index.indexer_between_time('1:15', '02:00')]
#
# AttributeError: 'RangeIndex' object has no attribute 'indexer_between_time'

# %%
m = df % 3 == 0
m

# %%
print(m)
# Out:
#        A      B
# 0   True  False
# 1  False   True
# 2  False  False
# 3   True  False
# 4  False   True

# %%
df.where(m, 0)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
s1 = pd.Series(np.random.randn(5), index=list(range(0,10,2)))

# %%
s1
# Out:
# 0    0.092306
# 2   -0.346650
# 4    0.229307
# 6    1.363177
# 8   -0.514946
# dtype: float64

# %%
s2 = s1.iloc[:3]

# %%
s2
# Out:
# 0    0.092306
# 2   -0.346650
# 4    0.229307
# dtype: float64

# %%
s1[2]
# Out:
# -0.34664965675870651

# %%
df1 = pd.DataFrame(np.random.randn(6,4),
                   index=list(range(0,12,2)),
                   columns=list(range(0,8,2)))

# %%
df1
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>2</th>
#       <th>4</th>
#       <th>6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.868640</td>
#       <td>1.225030</td>
#       <td>0.593797</td>
#       <td>1.088535</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.180422</td>
#       <td>-0.387538</td>
#       <td>-0.181816</td>
#       <td>-0.111929</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.745571</td>
#       <td>0.374735</td>
#       <td>0.569291</td>
#       <td>0.064634</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-1.090655</td>
#       <td>0.976275</td>
#       <td>-0.039989</td>
#       <td>-0.724808</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.903983</td>
#       <td>-0.292476</td>
#       <td>-0.514311</td>
#       <td>0.138748</td>
#     </tr>
#     <tr>
#       <th>10</th>
# ...

# %%
df1[-1:].index.values[0]
# Out:
# 10

# %%
import pandas as pd, numpy as np

df1 = pd.DataFrame(np.random.randn(6,4),
                   index=list(range(0,12,2)),
                   columns=list(range(0,8,2)))
df1
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>2</th>
#       <th>4</th>
#       <th>6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.117853</td>
#       <td>0.843729</td>
#       <td>0.252699</td>
#       <td>0.894914</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.058752</td>
#       <td>0.899434</td>
#       <td>0.528175</td>
#       <td>-0.613840</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.313260</td>
#       <td>-0.144499</td>
#       <td>1.001737</td>
#       <td>1.381238</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.641879</td>
#       <td>-1.603697</td>
#       <td>1.254309</td>
#       <td>-0.597999</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.602738</td>
#       <td>-0.652832</td>
#       <td>-0.358163</td>
#       <td>1.635520</td>
#     </tr>
#     <tr>
#       <th>10</th>
# ...

# %%
list(df1)
# Out:
# [0, 2, 4, 6]

# %%
print(3 in list(df1))
# Out:
# False

# %%
list(df1[[0,2]])
# Out:
# [0, 2]

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %%
list = []
# Out:
# 0

# %%
import pandas as pd
df = pd.DataFrame()

# %%
df.empty
# Out:
# True

# %%
list.empty
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-39d9cd0be3ad> in <module>()
# ----> 1 list.empty
#
# AttributeError: 'list' object has no attribute 'empty'

# %%
def check_frame(**kwargs):
    frame = kwargs.get('frame')
   # if frame is not None and isinstance(frame, pd.DataFrame) \
   #     and not frame.empty:
   #     print("Dataframe is empty!")
    import pandas as pd
    if frame is None:
        print("Nothing")
    else:
        if isinstance(frame, pd.DataFrame):
            print("Rows in dataframe: ", len(frame))
        else:
            print("Not a Dataframe")

# %%
import pandas as pd
df = pd.DataFrame()
check_frame(frame=45)
# Out:
# Not a Dataframe

# %%
def test_var_args_call(arg1, **kwargs):
    arg2 = kwargs.get('arg2')
    arg3 = kwargs.get('arg3')
    print("arg1:", arg1)
    print("arg2:", arg2)
    print("arg3:", arg3)

# %%
kwargs = {"arg2": 2}
test_var_args_call(1,arg3="Pete")
# Out:
# arg1: 1
# arg2: None
# arg3: Pete

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:admin@0.0.0.0/pkdemo')
marketdata_df = pd.read_sql_table(table_name="marketdata", con=engine, index_col='CARVER')
marketdata_df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>QUANDL</th>
#       <th>IB</th>
#       <th>SECTYPE</th>
#       <th>CURRENCY</th>
#       <th>Q_EXCHANGE</th>
#       <th>IB_EXCHANGE</th>
#       <th>MULTIPLIER</th>
#     </tr>
#     <tr>
#       <th>CARVER</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AEX</th>
#       <td>FTI</td>
#       <td>EOE</td>
#       <td>FUT</td>
#       <td>EUR</td>
#       <td>LIFFE</td>
#       <td>FTA</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>AUD</th>
#       <td>AD</td>
#       <td>AUD</td>
#       <td>FUT</td>
#       <td>USD</td>
#       <td>CME</td>
#       <td>GLOBEX</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>BOBL</th>
#       <td>FGBM</td>
#       <td>GBM</td>
#       <td>FUT</td>
# ...

# %%
ser = marketdata_df.loc['EDOLLAR']

# %%
ser
# Out:
# QUANDL             ED
# IB                 GE
# SECTYPE           FUT
# CURRENCY          USD
# Q_EXCHANGE        CME
# IB_EXCHANGE    GLOBEX
# MULTIPLIER          0
# Name: EDOLLAR, dtype: object

# %%
dict = {"QUANDL":"ED","IB":"GE","SECTYPE":"FUT","CURRENCY":"USD",
        "Q_EXCHANGE" :"CME","IB_EXCHANGE" :"GLOBEX","MULTIPLIER":0}

# %%
print(dict)

# %%
series = pd.Series(dict)
series
# Out:
# CURRENCY          USD
# IB                 GE
# IB_EXCHANGE    GLOBEX
# MULTIPLIER          0
# QUANDL             ED
# Q_EXCHANGE        CME
# SECTYPE           FUT
# dtype: object

# %%
print(series['QUANDL'])
# Out:
# ED

# %%
series['IB']
# Out:
# 'GE'

# %%
series['MULTIPLIER']
# Out:
# 0

# %%
import pandas as pd
from dbutils import *
from dbutils import panama
from dbutils.panama import *

from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:admin@0.0.0.0/pkdemo')
#start_date = '20170605'
maturity = '202006'
mkt_ser = pd.Series({"QUANDL":"ED","IB":"GE",
                           "SECTYPE":"FUT","CURRENCY":"USD",
                           "Q_EXCHANGE" :"CME","IB_EXCHANGE" :"GLOBEX",
                           "MULTIPLIER":0})
result = q_download(engine, "EDOLLAR", maturity)
print(result)

print("Pete Andrew")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-7311cbd446c5> in <module>()
#       1 import pandas as pd
#       2 from dbutils import *
# ----> 3 from dbutils import panama
#       4 from dbutils.panama import *
#       5
#
# /home/lope/PycharmProjects/notebook/dbutils/panama.py in <module>()
#       1 from accessrights import q_access_key
# ----> 2 import quandl
#       3 import pandas as pd
#       4 from wrapper_v2 import IBWrapper, IBclient
#       5 from swigibpy import Contract as IBcontract
#
# /home/lope/envs/notebook/lib/python3.5/site-packages/quandl/__init__.py in <module>()
#       9 from .model.datatable import Datatable
#      10 from .model.data import Data
# ---> 11 from .model.merged_dataset import MergedDataset
#      12 from .get import get
#      13 from .bulkdownload import bulkdownload
#
# ...
